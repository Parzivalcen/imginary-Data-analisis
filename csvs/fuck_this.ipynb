# %%
import pandas as pd
import os

# %%
files = [file for file in os.listdir('./Sales_Data')]

all_months_data=pd.DataFrame()
for file in files:
    df=pd.read_csv(f'./Sales_Data/{file}')
    all_months_data = pd.concat([all_months_data,df])
all_months_data.to_csv('all_data2.csv', index=False)

# %%
all_data = pd.read_csv('all_data2.csv')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   278797            Wired Headphones                1      11.99
# 1   278798        USB-C Charging Cable                2      11.95
# 2   278799    Apple Airpods Headphones                1      150.0
# 3   278800            27in FHD Monitor                1     149.99
# 4   278801  Bose SoundSport Headphones                1      99.99
#
#        Order Date                      Purchase Address
# 0  11/21/19 09:54   46 Park St, New York City, NY 10001
# 1  11/17/19 10:03      962 Hickory St, Austin, TX 73301
# 2  11/19/19 14:56  464 Cherry St, Los Angeles, CA 90001
# 3  11/25/19 22:24        649 10th St, Seattle, WA 98101
# 4  11/09/19 13:56         522 Hill St, Boston, MA 02215

# %% [markdown]
# # Clean Data

# %% [markdown]
# ## find NaN values and drop

# %%
all_data=all_data.dropna(how='all')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   278797            Wired Headphones                1      11.99
# 1   278798        USB-C Charging Cable                2      11.95
# 2   278799    Apple Airpods Headphones                1      150.0
# 3   278800            27in FHD Monitor                1     149.99
# 4   278801  Bose SoundSport Headphones                1      99.99
#
#        Order Date                      Purchase Address
# 0  11/21/19 09:54   46 Park St, New York City, NY 10001
# 1  11/17/19 10:03      962 Hickory St, Austin, TX 73301
# 2  11/19/19 14:56  464 Cherry St, Los Angeles, CA 90001
# 3  11/25/19 22:24        649 10th St, Seattle, WA 98101
# 4  11/09/19 13:56         522 Hill St, Boston, MA 02215

# %% [markdown]
# ## Find Strings in rows

# %%
temp_df = all_data[all_data['Order Date'].str[0:2]=='Or']
temp_df.head()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 1172  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1519  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1620  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1726  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1891  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address
# 1172  Purchase Address
# 1519  Purchase Address
# 1620  Purchase Address
# 1726  Purchase Address
# 1891  Purchase Address

# %%
# discard the rows w/ string
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   278797            Wired Headphones                1      11.99
# 1   278798        USB-C Charging Cable                2      11.95
# 2   278799    Apple Airpods Headphones                1      150.0
# 3   278800            27in FHD Monitor                1     149.99
# 4   278801  Bose SoundSport Headphones                1      99.99
#
#        Order Date                      Purchase Address
# 0  11/21/19 09:54   46 Park St, New York City, NY 10001
# 1  11/17/19 10:03      962 Hickory St, Austin, TX 73301
# 2  11/19/19 14:56  464 Cherry St, Los Angeles, CA 90001
# 3  11/25/19 22:24        649 10th St, Seattle, WA 98101
# 4  11/09/19 13:56         522 Hill St, Boston, MA 02215

# %% [markdown]
# ## Convert to the correct dtype

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   278797            Wired Headphones                 1       11.99
# 1   278798        USB-C Charging Cable                 2       11.95
# 2   278799    Apple Airpods Headphones                 1      150.00
# 3   278800            27in FHD Monitor                 1      149.99
# 4   278801  Bose SoundSport Headphones                 1       99.99
#
#        Order Date                      Purchase Address
# 0  11/21/19 09:54   46 Park St, New York City, NY 10001
# 1  11/17/19 10:03      962 Hickory St, Austin, TX 73301
# 2  11/19/19 14:56  464 Cherry St, Los Angeles, CA 90001
# 3  11/25/19 22:24        649 10th St, Seattle, WA 98101
# 4  11/09/19 13:56         522 Hill St, Boston, MA 02215

# %% [markdown]
# ## Create columns

# %% [markdown]
# ### Sales column

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   278797            Wired Headphones                 1       11.99
# 1   278798        USB-C Charging Cable                 2       11.95
# 2   278799    Apple Airpods Headphones                 1      150.00
# 3   278800            27in FHD Monitor                 1      149.99
# 4   278801  Bose SoundSport Headphones                 1       99.99
#
#        Order Date                      Purchase Address   Sales
# 0  11/21/19 09:54   46 Park St, New York City, NY 10001   11.99
# 1  11/17/19 10:03      962 Hickory St, Austin, TX 73301   23.90
# 2  11/19/19 14:56  464 Cherry St, Los Angeles, CA 90001  150.00
# 3  11/25/19 22:24        649 10th St, Seattle, WA 98101  149.99
# 4  11/09/19 13:56         522 Hill St, Boston, MA 02215   99.99

# %% [markdown]
# ### Month column

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Order Date'].str[0:2].astype('int32')
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   278797            Wired Headphones                 1       11.99
# 1   278798        USB-C Charging Cable                 2       11.95
# 2   278799    Apple Airpods Headphones                 1      150.00
# 3   278800            27in FHD Monitor                 1      149.99
# 4   278801  Bose SoundSport Headphones                 1       99.99
#
#        Order Date                      Purchase Address   Sales  Month
# 0  11/21/19 09:54   46 Park St, New York City, NY 10001   11.99     11
# 1  11/17/19 10:03      962 Hickory St, Austin, TX 73301   23.90     11
# 2  11/19/19 14:56  464 Cherry St, Los Angeles, CA 90001  150.00     11
# 3  11/25/19 22:24        649 10th St, Seattle, WA 98101  149.99     11
# 4  11/09/19 13:56         522 Hill St, Boston, MA 02215   99.99     11

# %% [markdown]
# ### City column

# %%
def get_city(address):
    return address.split(',')[1]
def get_state(address):
    return address.split(',')[2].split(' ')[1]

all_data['City'] = all_data['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")

all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   278797            Wired Headphones                 1       11.99
# 1   278798        USB-C Charging Cable                 2       11.95
# 2   278799    Apple Airpods Headphones                 1      150.00
# 3   278800            27in FHD Monitor                 1      149.99
# 4   278801  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                      Purchase Address   Sales  Month  \
# 0 2019-11-21 09:54:00   46 Park St, New York City, NY 10001   11.99     11
# 1 2019-11-17 10:03:00      962 Hickory St, Austin, TX 73301   23.90     11
# 2 2019-11-19 14:56:00  464 Cherry St, Los Angeles, CA 90001  150.00     11
# 3 2019-11-25 22:24:00        649 10th St, Seattle, WA 98101  149.99     11
# 4 2019-11-09 13:56:00         522 Hill St, Boston, MA 02215   99.99     11
#
#                   City  Hour  Minute
# 0   New York City (NY)     9      54
# 1          Austin (TX)    10       3
# 2     Los Angeles (CA)    14      56
# 3         Seattle (WA)    22      24
# 4          Boston (MA)    13      56

# %% [markdown]
# ## Find the month w/ most Sales

# %%
results = all_data.groupby('Month').sum()
results
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
import matplotlib.pyplot as plt
import numpy as np
months = np.arange(1,13)
plt.bar(months, results['Sales'])
plt.xticks(months)
plt.title('Monthly Sales')
plt.ylabel('Sales in Millions')
plt.xlabel('Months')
plt.show()

# %%
# December obviously had the most sales, probably because of Christmas, we had to check what
# happened on April, sales seem a little higher.
all_data.to_csv('first_plot.csv')

# %% [markdown]
# ## which City had the most Sales

# %%
cities = all_data.groupby('City').sum()
cities
# Out:
#                      Quantity Ordered    Price Each         Sales   Month
# City
#  Atlanta (GA)                   16602  2.779908e+06  2.795499e+06  104794
#  Austin (TX)                    11153  1.809874e+06  1.819582e+06   69829
#  Boston (MA)                    22528  3.637410e+06  3.661642e+06  141112
#  Dallas (TX)                    16730  2.752628e+06  2.767975e+06  104620
#  Los Angeles (CA)               33289  5.421435e+06  5.452571e+06  208325
#  New York City (NY)             27932  4.635371e+06  4.664317e+06  175741
#  Portland (ME)                   2750  4.471893e+05  4.497583e+05   17144
#  Portland (OR)                  11303  1.860558e+06  1.870732e+06   70621
#  San Francisco (CA)             50239  8.211462e+06  8.262204e+06  315520
#  Seattle (WA)                   16553  2.733296e+06  2.747755e+06  104941

# %% [markdown]
# ## Plot

# %%
cities_order =[city for city, df in all_data.groupby('City')]

plt.bar(cities_order, cities['Sales'])

plt.xticks(cities_order, rotation='vertical', size=8)

plt.title('Most Sales')
plt.ylabel('Sales in Millions')
plt.xlabel('Cities')
plt.show()
# San Francisco was the city w/ most sales we should probably look into it.
# what are we doing wright there
# We definitely need to look into Portland, it looks bad, we should probably Close there.

# %% [markdown]
# ## At what time we should display ads?

# %% [markdown]
# ### Convert Order Date to DateTime.

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   278797            Wired Headphones                 1       11.99
# 1   278798        USB-C Charging Cable                 2       11.95
# 2   278799    Apple Airpods Headphones                 1      150.00
# 3   278800            27in FHD Monitor                 1      149.99
# 4   278801  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                      Purchase Address   Sales  Month  \
# 0 2019-11-21 09:54:00   46 Park St, New York City, NY 10001   11.99     11
# 1 2019-11-17 10:03:00      962 Hickory St, Austin, TX 73301   23.90     11
# 2 2019-11-19 14:56:00  464 Cherry St, Los Angeles, CA 90001  150.00     11
# 3 2019-11-25 22:24:00        649 10th St, Seattle, WA 98101  149.99     11
# 4 2019-11-09 13:56:00         522 Hill St, Boston, MA 02215   99.99     11
#
#                   City
# 0   New York City (NY)
# 1          Austin (TX)
# 2     Los Angeles (CA)
# 3         Seattle (WA)
# 4          Boston (MA)

# %% [markdown]
# ### Create hour column

# %%
all_data['Hour']=all_data['Order Date'].dt.hour
all_data['Minute']=all_data['Order Date'].dt.minute
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   278797            Wired Headphones                 1       11.99
# 1   278798        USB-C Charging Cable                 2       11.95
# 2   278799    Apple Airpods Headphones                 1      150.00
# 3   278800            27in FHD Monitor                 1      149.99
# 4   278801  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                      Purchase Address   Sales  Month  \
# 0 2019-11-21 09:54:00   46 Park St, New York City, NY 10001   11.99     11
# 1 2019-11-17 10:03:00      962 Hickory St, Austin, TX 73301   23.90     11
# 2 2019-11-19 14:56:00  464 Cherry St, Los Angeles, CA 90001  150.00     11
# 3 2019-11-25 22:24:00        649 10th St, Seattle, WA 98101  149.99     11
# 4 2019-11-09 13:56:00         522 Hill St, Boston, MA 02215   99.99     11
#
#                   City  Hour  Minute
# 0   New York City (NY)     9      54
# 1          Austin (TX)    10       3
# 2     Los Angeles (CA)    14      56
# 3         Seattle (WA)    22      24
# 4          Boston (MA)    13      56

# %%
all_data.to_csv('hour_minute.csv')

# %%
hours = [hour for hour, df in all_data.groupby('Hour')]
plt.plot(hours, all_data.groupby(['Hour']).count())
plt.xticks(hours)
plt.grid()

plt.title('Ads recomendation')
plt.xlabel('Time of the Day')
plt.ylabel('Number of Orders')
plt.show()
# we should run ads at around 10 to 10:30am and/or 06pm, a little before the times 
#when we have the most traffic

# %% [markdown]
# ## At which time we should run ads on portland to increase sales

# %% [markdown]
# ## what products are sold toghether more often

# %%
# check for same order id's
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 9     278806  Bose SoundSport Headphones                 1       99.99
# 10    278806             ThinkPad Laptop                 1      999.99
# 15    278811            Wired Headphones                 1       11.99
# 16    278811    Apple Airpods Headphones                 1      150.00
# 24    278819                      iPhone                 1      700.00
# 25    278819    Apple Airpods Headphones                 1      150.00
# 39    278833                      iPhone                 1      700.00
# 40    278833    Lightning Charging Cable                 2       14.95
# 47    278840  Bose SoundSport Headphones                 1       99.99
# 48    278840            27in FHD Monitor                 1      149.99
# 65    278857        USB-C Charging Cable                 1       11.95
# 66    278857      AAA Batteries (4-pack)                 2        2.99
# 151   278940    Apple Airpods Headphones                 1      150.00
# 152   278940      AAA Batteries (4-pack)                 4        2.99
# 156   278944                Google Phone                 1      600.00
# 157   278944  Bose SoundSport Headphones                 1       99.99
# 159   278946                      iPhone                 1      700.00
# 160   278946    Lightning Charging Cable                 1       14.95
# 161   278946            Wired Headphones                 1       11.99
# 185   278970                Google Phone                 1      600.00
#
#              Order Date                       Purchase Address   Sales  Month  \
# 9   2019-11-19 19:12:00           174 2nd St, Boston, MA 02215   99.99     11
# 10  2019-11-19 19:12:00           174 2nd St, Boston, MA 02215  999.99     11
# 15  2019-11-06 16:01:00     99 Elm St, San Francisco, CA 94016   11.99     11
# 16  2019-11-06 16:01:00     99 Elm St, San Francisco, CA 94016  150.00     11
# 24  2019-11-04 06:20:00  880 Maple St, New York City, NY 10001  700.00     11
# 25  2019-11-04 06:20:00  880 Maple St, New York City, NY 10001  150.00     11
# 39  2019-11-04 10:34:00   700 Pine St, San Francisco, CA 94016  700.00     11
# 40  2019-11-04 10:34:00   700 Pine St, San Francisco, CA 94016   29.90     11
# 47  2019-11-23 20:46:00   490 Walnut St, Los Angeles, CA 90001   99.99     11
# 48  2019-11-23 20:46:00   490 Walnut St, Los Angeles, CA 90001  149.99     11
# 65  2019-11-30 15:37:00   150 Wilson St, Los Angeles, CA 90001   11.95     11
# 66  2019-11-30 15:37:00   150 Wilson St, Los Angeles, CA 90001    5.98     11
# 151 2019-11-23 10:51:00           140 2nd St, Boston, MA 02215  150.00     11
# 152 2019-11-23 10:51:00           140 2nd St, Boston, MA 02215   11.96     11
# 156 2019-11-14 22:19:00      600 Willow St, Portland, OR 97035  600.00     11
# 157 2019-11-14 22:19:00      600 Willow St, Portland, OR 97035   99.99     11
# 159 2019-11-19 18:25:00    361 9th St, San Francisco, CA 94016  700.00     11
# 160 2019-11-19 18:25:00    361 9th St, San Francisco, CA 94016   14.95     11
# 161 2019-11-19 18:25:00    361 9th St, San Francisco, CA 94016   11.99     11
# 185 2019-11-21 13:36:00    21 14th St, San Francisco, CA 94016  600.00     11
#
#                     City  Hour  Minute
# 9            Boston (MA)    19      12
# 10           Boston (MA)    19      12
# 15    San Francisco (CA)    16       1
# 16    San Francisco (CA)    16       1
# 24    New York City (NY)     6      20
# 25    New York City (NY)     6      20
# 39    San Francisco (CA)    10      34
# 40    San Francisco (CA)    10      34
# 47      Los Angeles (CA)    20      46
# 48      Los Angeles (CA)    20      46
# 65      Los Angeles (CA)    15      37
# 66      Los Angeles (CA)    15      37
# 151          Boston (MA)    10      51
# 152          Boston (MA)    10      51
# 156        Portland (OR)    22      19
# 157        Portland (OR)    22      19
# 159   San Francisco (CA)    18      25
# 160   San Francisco (CA)    18      25
# 161   San Francisco (CA)    18      25
# 185   San Francisco (CA)    13      36

# %% [markdown]
# ### join products w/ the same order id

# %%
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df = df[['Order ID', 'Grouped']].drop_duplicates()
df.head()
# Out:
# <ipython-input-60-ef83edd6e4b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#    Order ID                                      Grouped
# 9    278806   Bose SoundSport Headphones,ThinkPad Laptop
# 15   278811    Wired Headphones,Apple Airpods Headphones
# 24   278819              iPhone,Apple Airpods Headphones
# 39   278833              iPhone,Lightning Charging Cable
# 47   278840  Bose SoundSport Headphones,27in FHD Monitor

# %%
from itertools import combinations
from collections import Counter
count = Counter()
for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list,2)))
count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %%
df.to_csv('most_common.csv')
